# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
mortaile=pd.read_excel(r"C:\Users\HP SMART\Desktop\training_data.xlsx")

# %%
mortaile.head()
# Out:
#    ID              Severity Ventilation  Mean Age  % Male  Any Comorbidity  \
# 0   1                   All        Both       NaN  0.6230           0.4760
# 1   1  Severe/Critical Only        Both       NaN  0.7037           0.6667
# 2   1                   All        Both       NaN  0.5912           0.4015
# 3   2                   All        Both       NaN  0.6030              NaN
# 4   2                   All        Both       NaN  0.6160              NaN
#
#    Hypertension  Diabetes  Cardiovascular Disease (incl. CAD)  \
# 0        0.3000    0.1900                              0.0800
# 1        0.4815    0.3148                              0.2407
# 2        0.2336    0.1387                              0.0146
# 3           NaN    0.1160                                 NaN
# 4           NaN    0.1010                                 NaN
#
#    Chronic obstructive lung (COPD)     ...       Unnamed: 81  Unnamed: 82  \
# ...

# %%
mortaile.describe()
# Out:
#                ID    Mean Age      % Male  Any Comorbidity  Hypertension  \
# count  475.000000  252.000000  430.000000        222.00000    309.000000
# mean    94.324211   51.093536    0.547413          0.48413      0.286662
# std     51.058213   18.572915    0.263608          0.35929      0.288207
# min      1.000000    0.170000    0.000000          0.00000      0.000000
# 25%     58.500000   43.300000    0.451175          0.18050      0.078000
# 50%     96.000000   52.450000    0.540600          0.40075      0.206000
# 75%    131.500000   64.000000    0.670000          0.82000      0.395000
# max    199.000000  100.000000    1.000000          1.00000      1.000000
#
#          Diabetes  Cardiovascular Disease (incl. CAD)  \
# count  325.000000                          295.000000
# mean     0.147790                            0.142180
# std      0.201715                            0.241088
# min      0.000000                            0.000000
# ...

# %%
mortaile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 475 entries, 0 to 474
# Data columns (total 91 columns):
# ID                                          475 non-null int64
# Severity                                    458 non-null object
# Ventilation                                 301 non-null object
# Mean Age                                    252 non-null float64
# % Male                                      430 non-null float64
# Any Comorbidity                             222 non-null float64
# Hypertension                                309 non-null float64
# Diabetes                                    325 non-null float64
# Cardiovascular Disease (incl. CAD)          295 non-null float64
# Chronic obstructive lung (COPD)             262 non-null float64
# Cancer (Any)                                233 non-null float64
# Liver Disease (any)                         192 non-null float64
# Cerebrovascular Disease                     173 non-null float64
# ...

# %%
mortaile=mortaile.iloc[:,0:55]

# %%
mortaile.isnull().sum()
# Out:
# ID                                            0
# Severity                                     17
# Ventilation                                 174
# Mean Age                                    223
# % Male                                       45
# Any Comorbidity                             253
# Hypertension                                166
# Diabetes                                    150
# Cardiovascular Disease (incl. CAD)          180
# Chronic obstructive lung (COPD)             213
# Cancer (Any)                                242
# Liver Disease (any)                         283
# Cerebrovascular Disease                     302
# Chronic kidney/renal disease                225
# Other                                       276
# Fever (temperature ≥37·3°C)                 119
# Average temperature (celsius)               411
# Max temperature (celsius)                   421
# Respiratory rate > 24 breaths per min       437
# Cough                                       135
# ...

# %%
mortaile['ICU length of stay, days'].replace({'na':0},inplace=True)
mortaile['Hospital length of stay, days'].replace({'na':12},inplace=True)
mortaile['Mortality'].replace({'na':0},inplace=True)
mortaile['Mortality'].replace({'0%%':0},inplace=True)

# %%
mortaile.Severity=mortaile.Severity.fillna('All')
mortaile.Ventilation=mortaile.Ventilation.fillna('Both')
mortaile['Mean Age']=mortaile['Mean Age'].fillna(mortaile['Mean Age'].median())
mortaile['% Male']=mortaile['% Male'].fillna(mortaile['% Male'].median())
mortaile['Any Comorbidity']=mortaile['Any Comorbidity'].fillna(mortaile['Any Comorbidity'].median())
mortaile['Hypertension']=mortaile['Hypertension'].fillna(mortaile['Hypertension'].median())
mortaile['Diabetes']=mortaile['Diabetes'].fillna(mortaile['Diabetes'].median())
mortaile['Cardiovascular Disease (incl. CAD)']=mortaile['Cardiovascular Disease (incl. CAD)'].fillna(mortaile['Cardiovascular Disease (incl. CAD)'].median())
mortaile['Chronic obstructive lung (COPD)']=mortaile['Chronic obstructive lung (COPD)'].fillna(mortaile['Chronic obstructive lung (COPD)'].median())
mortaile['Cancer (Any)']=mortaile['Cancer (Any)'].fillna(mortaile['Cancer (Any)'].median())
mortaile['Liver Disease (any)']=mortaile['Liver Disease (any)'].fillna(mortaile['Liver Disease (any)'].median())
mortaile['Cerebrovascular Disease']=mortaile['Cerebrovascular Disease'].fillna(mortaile['Cerebrovascular Disease'].median())
mortaile['Chronic kidney/renal disease']=mortaile['Chronic kidney/renal disease'].fillna(mortaile['Chronic kidney/renal disease'].median())

# %%
mortaile.isnull().sum()
# Out:
# ID                                            0
# Severity                                      0
# Ventilation                                   0
# Mean Age                                      0
# % Male                                        0
# Any Comorbidity                               0
# Hypertension                                  0
# Diabetes                                      0
# Cardiovascular Disease (incl. CAD)            0
# Chronic obstructive lung (COPD)               0
# Cancer (Any)                                  0
# Liver Disease (any)                           0
# Cerebrovascular Disease                       0
# Chronic kidney/renal disease                  0
# Other                                       276
# Fever (temperature ≥37·3°C)                 119
# Average temperature (celsius)               411
# Max temperature (celsius)                   421
# Respiratory rate > 24 breaths per min       437
# Cough                                       135
# ...

# %%
mortaile.Other=mortaile.Other.fillna(mortaile.Other.median())
mortaile['Fever (temperature ≥37·3°C)']=mortaile['Fever (temperature ≥37·3°C)'].fillna(mortaile['Fever (temperature ≥37·3°C)'].median())
mortaile['Average temperature (celsius)']=mortaile['Average temperature (celsius)'].fillna(mortaile['Average temperature (celsius)'].median())
mortaile['Max temperature (celsius)']=mortaile['Max temperature (celsius)'].fillna(mortaile['Max temperature (celsius)'].median())
mortaile['Respiratory rate > 24 breaths per min']=mortaile['Respiratory rate > 24 breaths per min'].fillna(mortaile['Respiratory rate > 24 breaths per min'].median())
mortaile.Cough=mortaile.Cough.fillna(mortaile.Cough.median())
mortaile['Shortness of Breath (dyspnoea)']=mortaile['Shortness of Breath (dyspnoea)'].fillna(mortaile['Shortness of Breath (dyspnoea)'].median())
mortaile.Headache=mortaile.Headache.fillna(mortaile.Headache.median())
mortaile['Sputum (/Expectoration)']=mortaile['Sputum (/Expectoration)'].fillna(mortaile['Sputum (/Expectoration)'].median())
mortaile['Myalgia (Muscle Pain)']=mortaile['Myalgia (Muscle Pain)'].fillna(mortaile['Myalgia (Muscle Pain)'].median())
mortaile.Fatigue=mortaile.Fatigue.fillna(mortaile.Fatigue.median())
mortaile.Diarrhoea=mortaile.Diarrhoea.fillna(mortaile.Diarrhoea.median())
mortaile['Nausea or Vomiting']=mortaile['Nausea or Vomiting'].fillna(mortaile['Nausea or Vomiting'].median())
mortaile['Loss of Appetite/Anorexia']=mortaile['Loss of Appetite/Anorexia'].fillna(mortaile['Loss of Appetite/Anorexia'].median())

# %%
mortaile.isnull().sum()
# Out:
# ID                                            0
# Severity                                      0
# Ventilation                                   0
# Mean Age                                      0
# % Male                                        0
# Any Comorbidity                               0
# Hypertension                                  0
# Diabetes                                      0
# Cardiovascular Disease (incl. CAD)            0
# Chronic obstructive lung (COPD)               0
# Cancer (Any)                                  0
# Liver Disease (any)                           0
# Cerebrovascular Disease                       0
# Chronic kidney/renal disease                  0
# Other                                         0
# Fever (temperature ≥37·3°C)                   0
# Average temperature (celsius)                 0
# Max temperature (celsius)                     0
# Respiratory rate > 24 breaths per min         0
# Cough                                         0
# ...

# %%
mortaile['Disease Severity Asymptomatic']=mortaile['Disease Severity Asymptomatic'].fillna(mortaile['Disease Severity Asymptomatic'].median())
mortaile['Disease Severity General']=mortaile['Disease Severity General'].fillna(mortaile['Disease Severity General'].median())
mortaile['Disease Severity Severe']=mortaile['Disease Severity Severe'].fillna(mortaile['Disease Severity Severe'].median())
mortaile['Disease Severity Critical']=mortaile['Disease Severity Critical'].fillna(mortaile['Disease Severity Critical'].median())
mortaile['White Blood Cell Count (10^9/L) - Median']=mortaile['White Blood Cell Count (10^9/L) - Median'].fillna(mortaile['White Blood Cell Count (10^9/L) - Median'].median())
mortaile['White Blood Cell Count (10^9/L) - LQ']=mortaile['White Blood Cell Count (10^9/L) - LQ'].fillna(mortaile['White Blood Cell Count (10^9/L) - LQ'].median())
mortaile['White Blood Cell Count (10^9/L) - UQ']=mortaile['White Blood Cell Count (10^9/L) - UQ'].fillna(mortaile['White Blood Cell Count (10^9/L) - UQ'].median())
mortaile['Platelet Count (10^9/L) - Median']=mortaile['Platelet Count (10^9/L) - Median'].fillna(mortaile['Platelet Count (10^9/L) - Median'].median())
mortaile['Lymphocyte Count (10^9/L) - Median']=mortaile['Lymphocyte Count (10^9/L) - Median'].fillna(mortaile['Lymphocyte Count (10^9/L) - Median'].median())
mortaile['Lymphocyte Count (10^9/L) - LQ']=mortaile['Lymphocyte Count (10^9/L) - LQ'].fillna(mortaile['Lymphocyte Count (10^9/L) - LQ'].median())
mortaile['Lymphocyte Count (10^9/L) - UQ']=mortaile['Lymphocyte Count (10^9/L) - UQ'].fillna(mortaile['Lymphocyte Count (10^9/L) - UQ'].median())
mortaile['Platelet Count (10^9/L) - Median']=mortaile['Platelet Count (10^9/L) - Median'].fillna(mortaile['Platelet Count (10^9/L) - Median'].median())
mortaile['Platelet Count (10^9/L) - LQ']=mortaile['Platelet Count (10^9/L) - LQ'].fillna(mortaile['Platelet Count (10^9/L) - LQ'].median())
mortaile['Platelet Count (10^9/L) - UQ']=mortaile['Platelet Count (10^9/L) - UQ'].fillna(mortaile['Platelet Count (10^9/L) - UQ'].median())
mortaile['Hemoglobin (g/L) - Median']=mortaile['Hemoglobin (g/L) - Median'].fillna(mortaile['Hemoglobin (g/L) - Median'].median())
mortaile['Hemoglobin (g/L) - LQ']=mortaile['Hemoglobin (g/L) - LQ'].fillna(mortaile['Hemoglobin (g/L) - LQ'].median())
mortaile['Hemoglobin (g/L) - UQ']=mortaile['Hemoglobin (g/L) - UQ'].fillna(mortaile['Hemoglobin (g/L) - UQ'].median())
mortaile['Albumin (g/L)']=mortaile['Albumin (g/L)'].fillna(mortaile['Albumin (g/L)'].median())
mortaile['Alanine Aminotransferase (U/L)']=mortaile['Alanine Aminotransferase (U/L)'].fillna(mortaile['Alanine Aminotransferase (U/L)'].median())
mortaile['Aspartate Aminotransferase (U/L)']=mortaile['Aspartate Aminotransferase (U/L)'].fillna(mortaile['Aspartate Aminotransferase (U/L)'].median())
mortaile.Antibiotic=mortaile.Antibiotic.fillna(mortaile.Antibiotic.median())
mortaile['Antiviral (Any)']=mortaile['Antiviral (Any)'].fillna(mortaile['Antiviral (Any)'].median())
mortaile['Heart failure']=mortaile['Heart failure'].fillna(mortaile['Heart failure'].median())
mortaile['Acute kidney injury (AKI)']=mortaile['Acute kidney injury (AKI)'].fillna(mortaile['Acute kidney injury (AKI)'].median())
mortaile['Secondary infection/ Bacterial infection']=mortaile['Secondary infection/ Bacterial infection'].fillna(mortaile['Secondary infection/ Bacterial infection'].median())
mortaile['ICU length of stay, days']=mortaile['ICU length of stay, days'].fillna(mortaile['ICU length of stay, days'].median())
mortaile['Hospital length of stay, days']=mortaile['Hospital length of stay, days'].fillna(mortaile['Hospital length of stay, days'].median())

# %%
mortaile.isnull().sum()
# Out:
# ID                                          0
# Severity                                    0
# Ventilation                                 0
# Mean Age                                    0
# % Male                                      0
# Any Comorbidity                             0
# Hypertension                                0
# Diabetes                                    0
# Cardiovascular Disease (incl. CAD)          0
# Chronic obstructive lung (COPD)             0
# Cancer (Any)                                0
# Liver Disease (any)                         0
# Cerebrovascular Disease                     0
# Chronic kidney/renal disease                0
# Other                                       0
# Fever (temperature ≥37·3°C)                 0
# Average temperature (celsius)               0
# Max temperature (celsius)                   0
# Respiratory rate > 24 breaths per min       0
# Cough                                       0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
mortaile[mortaile.select_dtypes(include=['object']).columns]=mortaile[mortaile.select_dtypes(include=['object']).columns].apply(le.fit_transform)

# %%
mortaile.head()
# Out:
#    ID  Severity  Ventilation  Mean Age  % Male  Any Comorbidity  Hypertension  \
# 0   1         0            0     52.45  0.6230          0.47600        0.3000
# 1   1         6            0     52.45  0.7037          0.66670        0.4815
# 2   1         0            0     52.45  0.5912          0.40150        0.2336
# 3   2         0            0     52.45  0.6030          0.40075        0.2060
# 4   2         0            0     52.45  0.6160          0.40075        0.2060
#
#    Diabetes  Cardiovascular Disease (incl. CAD)  \
# 0    0.1900                              0.0800
# 1    0.3148                              0.2407
# 2    0.1387                              0.0146
# 3    0.1160                              0.0605
# 4    0.1010                              0.0605
#
#    Chronic obstructive lung (COPD)    ...      Alanine Aminotransferase (U/L)  \
# 0                          0.03000    ...                                30.0
# ...

# %%
plt.hist(mortaile)
# Out:
# ([array([  0.,   0.,   0.,   0.,   3., 145., 108.,  32.,  28., 159.]),
#   array([228.,   0.,   0.,   0.,   1.,   0.,   5.,   2.,  93., 146.]),
#   array([371.,   0.,   0.,   0.,   3.,   0.,  66.,  19.,  16.,   0.]),
#   array([  0.,   1.,   1.,   1.,   1.,   7.,   2.,  20.,  71., 371.]),
#   array([ 44.,  13., 115., 225.,  78.,   0.,   0.,   0.,   0.,   0.]),
#   array([ 44.,  38., 301.,  29.,  63.,   0.,   0.,   0.,   0.,   0.]),
#   array([106., 255.,  56.,  30.,  28.,   0.,   0.,   0.,   0.,   0.]),
#   array([344.,  94.,  23.,   2.,  12.,   0.,   0.,   0.,   0.,   0.]),
#   array([392.,  45.,  17.,   3.,  18.,   0.,   0.,   0.,   0.,   0.]),
#   array([442.,  21.,   7.,   0.,   5.,   0.,   0.,   0.,   0.,   0.]),
#   array([453.,  10.,   1.,   0.,  11.,   0.,   0.,   0.,   0.,   0.]),
#   array([462.,  11.,   1.,   0.,   1.,   0.,   0.,   0.,   0.,   0.]),
#   array([447.,  18.,   5.,   0.,   4.,   0.,   0.,   0.,   1.,   0.]),
# ...

# %%
mortaile.boxplot(column='Diabetes')

# %%
mortaile=pd.DataFrame(mortaile)
mortaile.head()
# Out:
#    ID  Severity  Ventilation  Mean Age  % Male  Any Comorbidity  Hypertension  \
# 0   1         0            0     52.45  0.6230          0.47600        0.3000
# 1   1         6            0     52.45  0.7037          0.66670        0.4815
# 2   1         0            0     52.45  0.5912          0.40150        0.2336
# 3   2         0            0     52.45  0.6030          0.40075        0.2060
# 4   2         0            0     52.45  0.6160          0.40075        0.2060
#
#    Diabetes  Cardiovascular Disease (incl. CAD)  \
# 0    0.1900                              0.0800
# 1    0.3148                              0.2407
# 2    0.1387                              0.0146
# 3    0.1160                              0.0605
# 4    0.1010                              0.0605
#
#    Chronic obstructive lung (COPD)    ...      Alanine Aminotransferase (U/L)  \
# 0                          0.03000    ...                                30.0
# ...

# %%
mortaile_x=mortaile.iloc[:,1:54]
mortaile_y=mortaile.iloc[:,-1]

# %%
mortaile_test=pd.read_excel(r"C:\Users\HP SMART\Desktop\test_data.xlsx")

# %%
mortaile_test.head()
# Out:
#     ID              Severity           Ventilation   Mean Age  % Male  \
# 0  155             Mild only                  Both  48.900000  0.3410
# 1  156  Severe/Critical Only                  Both        NaN  0.7500
# 2  156  Severe/Critical Only      Ventilation only        NaN  0.7900
# 3  156  Severe/Critical Only  Non-ventilation only        NaN  0.6800
# 4  157                   All                  Both  52.943333  0.4654
#
#    Any Comorbidity  Hypertension  Diabetes  \
# 0            0.325        0.1510    0.1190
# 1            0.680        0.2500    0.1700
# 2            0.740        0.2600    0.2400
# 3            0.580        0.2100    0.0500
# 4              NaN        0.2121    0.0938
#
#    Cardiovascular Disease (incl. CAD)  Chronic obstructive lung (COPD)  \
# 0                              0.0630                              NaN
# 1                              0.1100                           0.1100
# ...

# %%
mortaile_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 54 columns):
# ID                                          53 non-null int64
# Severity                                    53 non-null object
# Ventilation                                 46 non-null object
# Mean Age                                    36 non-null float64
# % Male                                      45 non-null float64
# Any Comorbidity                             14 non-null float64
# Hypertension                                26 non-null float64
# Diabetes                                    30 non-null float64
# Cardiovascular Disease (incl. CAD)          35 non-null float64
# Chronic obstructive lung (COPD)             24 non-null float64
# Cancer (Any)                                25 non-null float64
# Liver Disease (any)                         18 non-null float64
# Cerebrovascular Disease                     12 non-null float64
# ...

# %%
mortaile_test.describe()
# Out:
#                ID   Mean Age     % Male  Any Comorbidity  Hypertension  \
# count   53.000000  36.000000  45.000000        14.000000     26.000000
# mean   166.169811  47.260926   0.574596         0.527457      0.302204
# std      8.349887  10.593883   0.181174         0.240637      0.169915
# min    155.000000  21.000000   0.000000         0.000000      0.000000
# 25%    159.000000  40.725000   0.486000         0.414750      0.172200
# 50%    162.000000  45.150000   0.555000         0.523500      0.255000
# 75%    173.000000  52.745833   0.640000         0.667500      0.453750
# max    182.000000  69.000000   1.000000         0.991400      0.650000
#
#         Diabetes  Cardiovascular Disease (incl. CAD)  \
# count  30.000000                           35.000000
# mean    0.233683                            0.165971
# std     0.209209                            0.233346
# min     0.000000                            0.000000
# 25%     0.084200                            0.041000
# ...

# %%
mortaile_test.isnull().sum()
# Out:
# ID                                           0
# Severity                                     0
# Ventilation                                  7
# Mean Age                                    17
# % Male                                       8
# Any Comorbidity                             39
# Hypertension                                27
# Diabetes                                    23
# Cardiovascular Disease (incl. CAD)          18
# Chronic obstructive lung (COPD)             29
# Cancer (Any)                                28
# Liver Disease (any)                         35
# Cerebrovascular Disease                     41
# Chronic kidney/renal disease                37
# Other                                       51
# Fever (temperature ≥37·3°C)                 16
# Average temperature (celsius)               41
# Max temperature (celsius)                   50
# Respiratory rate > 24 breaths per min       42
# Cough                                       27
# ...

# %%
mortaile_test.Ventilation=mortaile_test.Ventilation.fillna('Both')
mortaile_test['Mean Age']=mortaile_test['Mean Age'].fillna(mortaile_test['Mean Age'].median())
mortaile_test['% Male']=mortaile_test['% Male'].fillna(mortaile_test['% Male'].median())
mortaile_test['Any Comorbidity']=mortaile_test['Any Comorbidity'].fillna(mortaile_test['Any Comorbidity'].median())
mortaile_test['Hypertension']=mortaile_test['Hypertension'].fillna(mortaile_test['Hypertension'].median())
mortaile_test['Diabetes']=mortaile_test['Diabetes'].fillna(mortaile_test['Diabetes'].median())
mortaile_test['Cardiovascular Disease (incl. CAD)']=mortaile_test['Cardiovascular Disease (incl. CAD)'].fillna(mortaile_test['Cardiovascular Disease (incl. CAD)'].median())
mortaile_test['Chronic obstructive lung (COPD)']=mortaile_test['Chronic obstructive lung (COPD)'].fillna(mortaile_test['Chronic obstructive lung (COPD)'].median())
mortaile_test['Cancer (Any)']=mortaile_test['Cancer (Any)'].fillna(mortaile_test['Cancer (Any)'].median())
mortaile_test['Liver Disease (any)']=mortaile_test['Liver Disease (any)'].fillna(mortaile_test['Liver Disease (any)'].median())
mortaile_test['Cerebrovascular Disease']=mortaile_test['Cerebrovascular Disease'].fillna(mortaile_test['Cerebrovascular Disease'].median())
mortaile_test['Chronic kidney/renal disease']=mortaile_test['Chronic kidney/renal disease'].fillna(mortaile_test['Chronic kidney/renal disease'].median())

# %%
mortaile_test.isnull().sum()
# Out:
# ID                                           0
# Severity                                     0
# Ventilation                                  0
# Mean Age                                     0
# % Male                                       0
# Any Comorbidity                              0
# Hypertension                                 0
# Diabetes                                     0
# Cardiovascular Disease (incl. CAD)           0
# Chronic obstructive lung (COPD)              0
# Cancer (Any)                                 0
# Liver Disease (any)                          0
# Cerebrovascular Disease                      0
# Chronic kidney/renal disease                 0
# Other                                       51
# Fever (temperature ≥37·3°C)                 16
# Average temperature (celsius)               41
# Max temperature (celsius)                   50
# Respiratory rate > 24 breaths per min       42
# Cough                                       27
# ...

# %%
mortaile_test.Other=mortaile_test.Other.fillna(mortaile_test.Other.median())
mortaile_test['Fever (temperature ≥37·3°C)']=mortaile_test['Fever (temperature ≥37·3°C)'].fillna(mortaile_test['Fever (temperature ≥37·3°C)'].median())
mortaile_test['Average temperature (celsius)']=mortaile_test['Average temperature (celsius)'].fillna(mortaile_test['Average temperature (celsius)'].median())
mortaile_test['Max temperature (celsius)']=mortaile_test['Max temperature (celsius)'].fillna(mortaile_test['Max temperature (celsius)'].median())
mortaile_test['Respiratory rate > 24 breaths per min']=mortaile_test['Respiratory rate > 24 breaths per min'].fillna(mortaile_test['Respiratory rate > 24 breaths per min'].median())
mortaile_test.Cough=mortaile_test.Cough.fillna(mortaile_test.Cough.median())
mortaile_test['Shortness of Breath (dyspnoea)']=mortaile_test['Shortness of Breath (dyspnoea)'].fillna(mortaile_test['Shortness of Breath (dyspnoea)'].median())
mortaile_test.Headache=mortaile_test.Headache.fillna(mortaile_test.Headache.median())
mortaile_test['Sputum (/Expectoration)']=mortaile_test['Sputum (/Expectoration)'].fillna(mortaile_test['Sputum (/Expectoration)'].median())
mortaile_test['Myalgia (Muscle Pain)']=mortaile_test['Myalgia (Muscle Pain)'].fillna(mortaile_test['Myalgia (Muscle Pain)'].median())
mortaile_test.Fatigue=mortaile_test.Fatigue.fillna(mortaile_test.Fatigue.median())
mortaile_test.Diarrhoea=mortaile_test.Diarrhoea.fillna(mortaile_test.Diarrhoea.median())
mortaile_test['Nausea or Vomiting']=mortaile_test['Nausea or Vomiting'].fillna(mortaile_test['Nausea or Vomiting'].median())
mortaile_test['Loss of Appetite/Anorexia']=mortaile_test['Loss of Appetite/Anorexia'].fillna(mortaile_test['Loss of Appetite/Anorexia'].median())

# %%
mortaile_test.isnull().sum()
# Out:
# ID                                           0
# Severity                                     0
# Ventilation                                  0
# Mean Age                                     0
# % Male                                       0
# Any Comorbidity                              0
# Hypertension                                 0
# Diabetes                                     0
# Cardiovascular Disease (incl. CAD)           0
# Chronic obstructive lung (COPD)              0
# Cancer (Any)                                 0
# Liver Disease (any)                          0
# Cerebrovascular Disease                      0
# Chronic kidney/renal disease                 0
# Other                                        0
# Fever (temperature ≥37·3°C)                  0
# Average temperature (celsius)                0
# Max temperature (celsius)                    0
# Respiratory rate > 24 breaths per min        0
# Cough                                        0
# ...

# %%
mortaile_test['Disease Severity Asymptomatic']=mortaile_test['Disease Severity Asymptomatic'].fillna(mortaile_test['Disease Severity Asymptomatic'].median())
mortaile_test['Disease Severity General']=mortaile_test['Disease Severity General'].fillna(mortaile_test['Disease Severity General'].median())
mortaile_test['Disease Severity Severe']=mortaile_test['Disease Severity Severe'].fillna(mortaile_test['Disease Severity Severe'].median())
mortaile_test['Disease Severity Critical']=mortaile_test['Disease Severity Critical'].fillna(mortaile_test['Disease Severity Critical'].median())
mortaile_test['White Blood Cell Count (10^9/L) - Median']=mortaile_test['White Blood Cell Count (10^9/L) - Median'].fillna(mortaile_test['White Blood Cell Count (10^9/L) - Median'].median())
mortaile_test['White Blood Cell Count (10^9/L) - LQ']=mortaile_test['White Blood Cell Count (10^9/L) - LQ'].fillna(mortaile_test['White Blood Cell Count (10^9/L) - LQ'].median())
mortaile_test['White Blood Cell Count (10^9/L) - UQ']=mortaile_test['White Blood Cell Count (10^9/L) - UQ'].fillna(mortaile_test['White Blood Cell Count (10^9/L) - UQ'].median())
mortaile_test['Platelet Count (10^9/L) - Median']=mortaile_test['Platelet Count (10^9/L) - Median'].fillna(mortaile_test['Platelet Count (10^9/L) - Median'].median())
mortaile_test['Lymphocyte Count (10^9/L) - Median']=mortaile_test['Lymphocyte Count (10^9/L) - Median'].fillna(mortaile_test['Lymphocyte Count (10^9/L) - Median'].median())
mortaile_test['Lymphocyte Count (10^9/L) - LQ']=mortaile_test['Lymphocyte Count (10^9/L) - LQ'].fillna(mortaile_test['Lymphocyte Count (10^9/L) - LQ'].median())
mortaile_test['Lymphocyte Count (10^9/L) - UQ']=mortaile_test['Lymphocyte Count (10^9/L) - UQ'].fillna(mortaile_test['Lymphocyte Count (10^9/L) - UQ'].median())
mortaile_test['Platelet Count (10^9/L) - Median']=mortaile_test['Platelet Count (10^9/L) - Median'].fillna(mortaile_test['Platelet Count (10^9/L) - Median'].median())
mortaile_test['Platelet Count (10^9/L) - LQ']=mortaile_test['Platelet Count (10^9/L) - LQ'].fillna(mortaile_test['Platelet Count (10^9/L) - LQ'].median())
mortaile_test['Platelet Count (10^9/L) - UQ']=mortaile_test['Platelet Count (10^9/L) - UQ'].fillna(mortaile_test['Platelet Count (10^9/L) - UQ'].median())
mortaile_test['Hemoglobin (g/L) - Median']=mortaile_test['Hemoglobin (g/L) - Median'].fillna(mortaile_test['Hemoglobin (g/L) - Median'].median())
mortaile_test['Hemoglobin (g/L) - LQ']=mortaile_test['Hemoglobin (g/L) - LQ'].fillna(mortaile_test['Hemoglobin (g/L) - LQ'].median())
mortaile_test['Hemoglobin (g/L) - UQ']=mortaile_test['Hemoglobin (g/L) - UQ'].fillna(mortaile_test['Hemoglobin (g/L) - UQ'].median())
mortaile_test['Albumin (g/L)']=mortaile_test['Albumin (g/L)'].fillna(mortaile_test['Albumin (g/L)'].median())
mortaile_test['Alanine Aminotransferase (U/L)']=mortaile_test['Alanine Aminotransferase (U/L)'].fillna(mortaile_test['Alanine Aminotransferase (U/L)'].median())
mortaile_test['Aspartate Aminotransferase (U/L)']=mortaile_test['Aspartate Aminotransferase (U/L)'].fillna(mortaile_test['Aspartate Aminotransferase (U/L)'].median())
mortaile_test.Antibiotic=mortaile_test.Antibiotic.fillna(mortaile_test.Antibiotic.median())
mortaile_test['Antiviral (Any)']=mortaile_test['Antiviral (Any)'].fillna(mortaile_test['Antiviral (Any)'].median())
mortaile_test['Heart failure']=mortaile_test['Heart failure'].fillna(mortaile_test['Heart failure'].median())
mortaile_test['Acute kidney injury (AKI)']=mortaile_test['Acute kidney injury (AKI)'].fillna(mortaile_test['Acute kidney injury (AKI)'].median())
mortaile_test['Secondary infection/ Bacterial infection']=mortaile_test['Secondary infection/ Bacterial infection'].fillna(mortaile_test['Secondary infection/ Bacterial infection'].median())
mortaile_test['ICU length of stay, days']=mortaile_test['ICU length of stay, days'].fillna(mortaile_test['ICU length of stay, days'].median())
mortaile_test['Hospital length of stay, days']=mortaile_test['Hospital length of stay, days'].fillna(mortaile_test['Hospital length of stay, days'].median())

# %%
mortaile_test.isnull().sum()
# Out:
# ID                                           0
# Severity                                     0
# Ventilation                                  0
# Mean Age                                     0
# % Male                                       0
# Any Comorbidity                              0
# Hypertension                                 0
# Diabetes                                     0
# Cardiovascular Disease (incl. CAD)           0
# Chronic obstructive lung (COPD)              0
# Cancer (Any)                                 0
# Liver Disease (any)                          0
# Cerebrovascular Disease                      0
# Chronic kidney/renal disease                 0
# Other                                        0
# Fever (temperature ≥37·3°C)                  0
# Average temperature (celsius)                0
# Max temperature (celsius)                    0
# Respiratory rate > 24 breaths per min        0
# Cough                                        0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
mortaile_test[mortaile_test.select_dtypes(include=['object']).columns]=mortaile_test[mortaile_test.select_dtypes(include=['object']).columns].apply(le.fit_transform)

# %%
mortaile_test.isnull().sum()
# Out:
# ID                                           0
# Severity                                     0
# Ventilation                                  0
# Mean Age                                     0
# % Male                                       0
# Any Comorbidity                              0
# Hypertension                                 0
# Diabetes                                     0
# Cardiovascular Disease (incl. CAD)           0
# Chronic obstructive lung (COPD)              0
# Cancer (Any)                                 0
# Liver Disease (any)                          0
# Cerebrovascular Disease                      0
# Chronic kidney/renal disease                 0
# Other                                        0
# Fever (temperature ≥37·3°C)                  0
# Average temperature (celsius)                0
# Max temperature (celsius)                    0
# Respiratory rate > 24 breaths per min        0
# Cough                                        0
# ...

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
from sklearn.feature_selection import RFE

# %%
rfe=RFE(reg,n_features_to_select=30)
rfe.fit(mortaile_x,mortaile_y)
rfe.support_
# Out:
# array([ True,  True, False,  True,  True,  True,  True,  True,  True,
#         True, False,  True,  True,  True, False, False,  True,  True,
#        False, False,  True,  True, False,  True, False,  True,  True,
#         True,  True, False, False,  True,  True, False,  True, False,
#         True, False, False, False, False, False, False, False, False,
#        False,  True,  True,  True,  True,  True, False, False])

# %%
rfe.support_=pd.Series(rfe.support_)
rfe.support_
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# 11     True
# 12     True
# 13     True
# 14    False
# 15    False
# 16     True
# 17     True
# 18    False
# 19    False
# 20     True
# 21     True
# 22    False
# 23     True
# 24    False
# 25     True
# 26     True
# 27     True
# 28     True
# 29    False
# 30    False
# 31     True
# 32     True
# 33    False
# 34     True
# 35    False
# 36     True
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46     True
# 47     True
# 48     True
# 49     True
# 50     True
# 51    False
# 52    False
# dtype: bool

# %%
mortaile2_x=mortaile.iloc[:,[0,1,3,4,5,6,7,8,9,11,12,13,16,17,20,21,23,24,25,26,27,28,31,32,34,36,46,47,48,49,50]]
mortaile2_y=mortaile_y

# %%
mortaile_test_x=mortaile_test.iloc[:,[0,1,3,4,5,6,7,8,9,11,12,13,16,17,20,21,23,24,25,26,27,28,31,32,34,36,46,47,48,49,50]]

# %%
reg.fit(mortaile2_x,mortaile2_y)
# Out:
# LinearRegression()

# %%
predict=reg.predict(mortaile_test_x)

# %%
df=pd.concat([mortaile_test.ID,pd.Series(predict)],axis=1)
df
# Out:
#      ID         0
# 0   155  0.050721
# 1   156  0.250379
# 2   156  0.285580
# 3   156  0.180796
# 4   157  0.164185
# 5   157  0.077847
# 6   157  0.101510
# 7   157  0.312274
# 8   158  0.099559
# 9   158  0.117156
# 10  158  0.061744
# 11  159  0.124564
# 12  159  0.155917
# 13  159  0.390794
# 14  160  0.009661
# 15  160  0.193013
# 16  160  0.147991
# 17  160  0.438039
# 18  160  0.274722
# 19  160 -0.065231
# 20  160  0.430089
# 21  161  0.158538
# 22  161  0.309582
# 23  161  0.785402
# 24  161  0.051739
# 25  162  0.097126
# 26  162  0.112475
# 27  162  0.068739
# 28  169  0.124229
# 29  169  0.072994
# 30  169  0.400495
# 31  170  0.107702
# 32  170  0.100920
# 33  170  0.073043
# 34  170  0.101554
# 35  170  0.095599
# 36  171  0.163704
# 37  171  0.174350
# 38  172  0.490779
# 39  173  0.165512
# 40  175  0.221170
# 41  175  0.138758
# 42  175  0.138758
# 43  175  0.138758
# 44  176  0.174952
# 45  176  0.272414
# 46  176  0.182970
# 47  177  0.122928
# 48  181  0.224991
# ...

# %%
df.rename(columns={0:'Mortality'},inplace=True)
df
# Out:
#      ID  Mortality
# 0   155   0.050721
# 1   156   0.250379
# 2   156   0.285580
# 3   156   0.180796
# 4   157   0.164185
# 5   157   0.077847
# 6   157   0.101510
# 7   157   0.312274
# 8   158   0.099559
# 9   158   0.117156
# 10  158   0.061744
# 11  159   0.124564
# 12  159   0.155917
# 13  159   0.390794
# 14  160   0.009661
# 15  160   0.193013
# 16  160   0.147991
# 17  160   0.438039
# 18  160   0.274722
# 19  160  -0.065231
# 20  160   0.430089
# 21  161   0.158538
# 22  161   0.309582
# 23  161   0.785402
# 24  161   0.051739
# 25  162   0.097126
# 26  162   0.112475
# 27  162   0.068739
# 28  169   0.124229
# 29  169   0.072994
# 30  169   0.400495
# 31  170   0.107702
# 32  170   0.100920
# 33  170   0.073043
# 34  170   0.101554
# 35  170   0.095599
# 36  171   0.163704
# 37  171   0.174350
# 38  172   0.490779
# 39  173   0.165512
# 40  175   0.221170
# 41  175   0.138758
# 42  175   0.138758
# 43  175   0.138758
# 44  176   0.174952
# 45  176   0.272414
# ...

# %%
df.to_csv(r'D:\submission.csv',index=False)
